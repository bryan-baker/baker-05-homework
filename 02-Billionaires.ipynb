# %% [markdown]
# # Homework 5, Part 2: Answer questions with pandas
#
# **Use the Excel file to answer the following questions.** This is a little more typical of what your data exploration will look like with pandas.

# %% [markdown]
# ## 0) Setup
#
# Import pandas **with the correct name** .

# %%
import pandas as pd

# %% [markdown]
# ## 1) Reading in an Excel file
#
# Use pandas to read in the `richpeople.xlsx` Excel file, saving it as a variable with the name we'll always use for a dataframe.
#
# > **TIP:** You will use `read_excel` instead of `read_csv`. Trying `read_excel` the first time will probably not work, you'll get an error message. Be sure to read the error carefully: *you probably need to install a new library before it will work, and the error tells you what the library is named*.

# %%
df = pd.read_excel('richpeople.xlsx')

# %% [markdown]
# ## 2) Checking your data
#
# Display the number of rows and columns in your data. Also display the names and data types of each column.

# %%
df
# Out:
#       year                          name  rank           citizenship  \
# 0     2014          A. Jerrold Perenchio   663         United States
# 1     2014            Abdulla Al Futtaim   687  United Arab Emirates
# 2     2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates
# 3     2014             Abdullah Al Rajhi   731          Saudi Arabia
# 4     2014              Abdulsamad Rabiu  1372               Nigeria
# ...    ...                           ...   ...                   ...
# 1648  2014                     Zhu Yicai  1154                 China
# 1649  2014                 Ziyad Manasir   609                Russia
# 1650  2014            Ziyaudin Magomedov  1372                Russia
# 1651  2014                  Zong Qinghou    94                 China
# 1652  2014            Zygmunt Solorz-Zak   446                Poland
#
#      countrycode  networthusbillion   selfmade              typeofwealth  \
# 0            USA                2.6  self-made                 executive
# 1            ARE                2.5  inherited                 inherited
# 2            ARE                4.8  inherited                 inherited
# 3            SAU                2.4  self-made         self-made finance
# 4            NGA                1.2  self-made       founder non-finance
# ...          ...                ...        ...                       ...
# 1648         CHN                1.5  self-made         self-made finance
# 1649         RUS                2.8  self-made  privatized and resources
# 1650         RUS                1.2  self-made  privatized and resources
# 1651         CHN               11.6  self-made       founder non-finance
# 1652         POL                3.5  self-made       founder non-finance
#
#      gender   age  ...    relationshiptocompany foundingdate gdpcurrentus  \
# 0      male  83.0  ...  former chairman and CEO       1955.0          NaN
# 1      male   NaN  ...                 relation       1930.0          NaN
# 2      male   NaN  ...                 relation       1960.0          NaN
# 3      male   NaN  ...                  founder       1957.0          NaN
# 4      male  54.0  ...                  founder       1988.0          NaN
# ...     ...   ...  ...                      ...          ...          ...
# 1648   male  49.0  ...                  founder       1993.0          NaN
# 1649   male  48.0  ...                  founder       1992.0          NaN
# 1650   male  45.0  ...                  founder       2004.0          NaN
# 1651   male  68.0  ...                  founder       1987.0          NaN
# 1652   male  57.0  ...                  founder       1992.0          NaN
#
#                  sourceofwealth  \
# 0         television, Univision
# 1     auto dealers, investments
# 2                   diversified
# 3                       banking
# 4          sugar, flour, cement
# ...                         ...
# 1648                diversified
# 1649               construction
# 1650                  port, gas
# 1651                  beverages
# 1652            TV broadcasting
#
#                                                notes  notes2  \
# 0     represented Marlon Brando and Elizabeth Taylor     NaN
# 1       company split between him and cousin in 2000     NaN
# 2                              inherited from father     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
# ...                                              ...     ...
# 1648                                             NaN     NaN
# 1649                         close ties with Gazprom     NaN
# 1650                                             NaN     NaN
# 1651                                             NaN     NaN
# 1652                                             NaN     NaN
#
#                                                  source  \
# 0          http://en.wikipedia.org/wiki/Jerry_Perenchio
# 1         http://en.wikipedia.org/wiki/Al-Futtaim_Group
# 2         http://en.wikipedia.org/wiki/Al-Ghurair_Group
# 3            http://en.wikipedia.org/wiki/Al-Rajhi_Bank
# 4       http://www.forbes.com/profile/abdulsamad-rabiu/
# ...                                                 ...
# 1648           http://www.forbes.com/profile/zhu-yicai/
# 1649       http://www.forbes.com/profile/ziyad-manasir/
# 1650         http://www.summagroup.ru/about/history/en/
# 1651          http://en.wikipedia.org/wiki/Zong_Qinghou
# 1652  http://en.wikipedia.org/wiki/Zygmunt_Solorz-%C...
#
#                                                source_2  \
# 0     http://www.forbes.com/profile/a-jerrold-perenc...
# 1     http://www.al-futtaim.ae/content/groupProfile.asp
# 2         http://www.alghurair.com/about-us/our-history
# 3     http://www.alrajhibank.com.sa/ar/investor-rela...
# 4     http://www.bloomberg.com/research/stocks/priva...
# ...                                                 ...
# 1648                                                NaN
# 1649  http://www.themoscowtimes.com/business/article...
# 1650  http://www.forbes.com/profile/ziyaudin-magomedov/
# 1651  http://mic.com/articles/39659/zong-qinghou-chi...
# 1652  No Mob Bosses in This Legal Strategy The New Y...
#
#                                                source_3 source_4
# 0     COLUMN ONE; A Hollywood Player Who Owns the Ga...      NaN
# 1                                                   NaN      NaN
# 2                                                   NaN      NaN
# 3     http://www.alrajhibank.com.sa/ar/about-us/page...      NaN
# 4                                                   NaN      NaN
# ...                                                 ...      ...
# 1648                                                NaN      NaN
# 1649                                                NaN      NaN
# 1650                                                NaN      NaN
# 1651                                                NaN      NaN
# 1652                                                NaN      NaN
#
# [1653 rows x 30 columns]

# %%
df.shape
# Out:
# (1653, 30)

# %%
df.dtypes
# Out:
# year                         int64
# name                        object
# rank                         int64
# citizenship                 object
# countrycode                 object
# networthusbillion          float64
# selfmade                    object
# typeofwealth                object
# gender                      object
# age                        float64
# industry                    object
# IndustryAggregates          object
# region                      object
# north                        int64
# politicalconnection        float64
# founder                      int64
# generationofinheritance     object
# sector                      object
# company                     object
# companytype                 object
# relationshiptocompany       object
# foundingdate               float64
# gdpcurrentus               float64
# sourceofwealth              object
# notes                       object
# notes2                      object
# source                      object
# source_2                    object
# source_3                    object
# source_4                    object
# dtype: object

# %% [markdown]
# ## 3) Who are the top 10 richest billionaires? Use the `networthusbillion` column.

# %%
df.sort_values(by= 'networthusbillion', ascending=False).head(10)
# Out:
#       year              name  rank    citizenship countrycode  \
# 184   2014        Bill Gates     1  United States         USA
# 226   2014  Carlos Slim Helu     2         Mexico         MEX
# 79    2014    Amancio Ortega     3          Spain         ESP
# 1562  2014    Warren Buffett     4  United States         USA
# 862   2014     Larry Ellison     5  United States         USA
# 339   2014        David Koch     6  United States         USA
# 247   2014      Charles Koch     6  United States         USA
# 1364  2014   Sheldon Adelson     8  United States         USA
# 280   2014    Christy Walton     9  United States         USA
# 724   2014        Jim Walton    10  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 184                76.0  self-made       founder non-finance    male  58.0
# 226                72.0  self-made  privatized and resources    male  74.0
# 79                 64.0  self-made       founder non-finance    male  77.0
# 1562               58.2  self-made       founder non-finance    male  83.0
# 862                48.0  self-made       founder non-finance    male  69.0
# 339                40.0  inherited                 inherited    male  73.0
# 247                40.0  inherited                 inherited    male  78.0
# 1364               38.0  self-made         self-made finance    male  80.0
# 280                36.7  inherited                 inherited  female  59.0
# 724                34.7  inherited                 inherited    male  66.0
#
#       ... relationshiptocompany foundingdate gdpcurrentus      sourceofwealth  \
# 184   ...               founder       1975.0          NaN           Microsoft
# 226   ...               founder       1990.0          NaN             telecom
# 79    ...               founder       1975.0          NaN              retail
# 1562  ...               founder       1839.0          NaN  Berkshire Hathaway
# 862   ...               founder       1977.0          NaN              Oracle
# 339   ...              relation       1940.0          NaN         diversified
# 247   ...              relation       1940.0          NaN         diversified
# 1364  ...               founder       1952.0          NaN             casinos
# 280   ...              relation       1962.0          NaN            Wal-Mart
# 724   ...              relation       1962.0          NaN            Wal-Mart
#
#                       notes  notes2  \
# 184                     NaN     NaN
# 226                     NaN     NaN
# 79                      NaN     NaN
# 1562                    NaN     NaN
# 862                     NaN     NaN
# 339   inherited from father     NaN
# 247   inherited from father     NaN
# 1364                    NaN     NaN
# 280                   widow     NaN
# 724   inherited from father     NaN
#
#                                                  source  \
# 184           http://www.forbes.com/profile/bill-gates/
# 226   http://www.ozy.com/provocateurs/carlos-slims-w...
# 79        http://www.forbes.com/profile/amancio-ortega/
# 1562  http://www.forbes.com/lists/2009/10/billionair...
# 862        http://www.forbes.com/profile/larry-ellison/
# 339   http://www.kochind.com/About_Koch/History_Time...
# 247   http://www.kochind.com/About_Koch/History_Time...
# 1364     http://www.forbes.com/profile/sheldon-adelson/
# 280       http://www.forbes.com/profile/christy-walton/
# 724           http://www.forbes.com/profile/jim-walton/
#
#                                                source_2 source_3 source_4
# 184                                                 NaN      NaN      NaN
# 226                                                 NaN      NaN      NaN
# 79                                                  NaN      NaN      NaN
# 1562  http://www.forbes.com/companies/berkshire-hath...      NaN      NaN
# 862   http://www.businessinsider.com/how-larry-ellis...      NaN      NaN
# 339                                                 NaN      NaN      NaN
# 247                                                 NaN      NaN      NaN
# 1364  http://lasvegassun.com/news/1996/nov/26/rat-pa...      NaN      NaN
# 280                                                 NaN      NaN      NaN
# 724                                                 NaN      NaN      NaN
#
# [10 rows x 30 columns]

# %% [markdown]
# ## 4) How many male billionaires are there compared to the number of female billionares? What percent is that? Do they have a different average wealth?
#
# > **TIP:** The last part uses `groupby`, but the count/percent part does not.
# > **TIP:** When I say "average," you can pick what kind of average you use.

# %%
pd.options.display.float_format = '{:,.2f}'.format
df.gender.value_counts(normalize=True)*100
# Out:
# male     89.11
# female   10.89
# Name: gender, dtype: float64

# %%
df[df.gender == 'male'].networthusbillion.mean()
# Out:
# 3.9027155465037335

# %%
df[df.gender == 'female'].networthusbillion.mean()
# Out:
# 3.9205555555555547

# %% [markdown]
# ## 5) What is the most common source/type of wealth? Is it different between males and females?
#
# > **TIP:** You know how to `groupby` and you know how to count how many times a value is in a column. Can you put them together???
# > **TIP:** Use percentages for this, it makes it a lot more readable.

# %%
df.typeofwealth.value_counts(normalize = True)* 100
# Out:
# inherited                  30.65
# founder non-finance        28.29
# self-made finance          20.84
# privatized and resources   11.63
# executive                   8.60
# Name: typeofwealth, dtype: float64

# %%
df.groupby(by= 'gender').typeofwealth.value_counts(normalize = True) * 100
# Out:
# gender  typeofwealth
# female  inherited                  78.89
#         founder non-finance        11.67
#         executive                   3.33
#         self-made finance           3.33
#         privatized and resources    2.78
# male    founder non-finance        30.32
#         inherited                  24.75
#         self-made finance          22.98
#         privatized and resources   12.71
#         executive                   9.25
# Name: typeofwealth, dtype: float64

# %% [markdown]
# ## 6) What companies have the most billionaires? Graph the top 5 as a horizontal bar graph.
#
# > **TIP:** First find the answer to the question, then just try to throw `.plot()` on the end
# >
# > **TIP:** You can use `.head()` on *anything*, not just your basic `df`
# >
# > **TIP:** You might feel like you should use `groupby`, but don't! There's an easier way to count.
# >
# > **TIP:** Make the largest bar be at the top of the graph
# >
# > **TIP:** If your chart seems... weird, think about where in the process you're sorting vs using `head`

# %%
pd.set_option("display.max_rows", 20)

# %%
df.company.value_counts().head().sort_values().plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 7) How much money do these billionaires have in total?

# %%
df.networthusbillion.sum()
# Out:
# 6454.400000000001

# %% [markdown]
# ## 8) What are the top 10 countries with the most money held by billionaires?
#
# I am **not** asking which country has the most billionaires - this is **total amount of money per country.**
#
# > **TIP:** Think about it in steps - "I want them organized by country," "I want their net worth," "I want to add it all up," and "I want 10 of them." Just chain it all together.

# %%
df.groupby('countrycode').networthusbillion.sum().head(10).sort_values(ascending=False)
# Out:
# countrycode
# BRA   192.20
# CAN   112.80
# AUS    85.40
# CHE    80.20
# CHL    41.30
# AUT    33.80
# ARE    14.60
# ARG    11.30
# BEL     8.00
# AGO     3.70
# Name: networthusbillion, dtype: float64

# %%
# Out:
#       year                          name  rank           citizenship  \
# 0     2014          A. Jerrold Perenchio   663         United States
# 1     2014            Abdulla Al Futtaim   687  United Arab Emirates
# 2     2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates
# 3     2014             Abdullah Al Rajhi   731          Saudi Arabia
# 4     2014              Abdulsamad Rabiu  1372               Nigeria
# ...    ...                           ...   ...                   ...
# 1648  2014                     Zhu Yicai  1154                 China
# 1649  2014                 Ziyad Manasir   609                Russia
# 1650  2014            Ziyaudin Magomedov  1372                Russia
# 1651  2014                  Zong Qinghou    94                 China
# 1652  2014            Zygmunt Solorz-Zak   446                Poland
#
#      countrycode  networthusbillion   selfmade              typeofwealth  \
# 0            USA               2.60  self-made                 executive
# 1            ARE               2.50  inherited                 inherited
# 2            ARE               4.80  inherited                 inherited
# 3            SAU               2.40  self-made         self-made finance
# 4            NGA               1.20  self-made       founder non-finance
# ...          ...                ...        ...                       ...
# 1648         CHN               1.50  self-made         self-made finance
# 1649         RUS               2.80  self-made  privatized and resources
# 1650         RUS               1.20  self-made  privatized and resources
# 1651         CHN              11.60  self-made       founder non-finance
# 1652         POL               3.50  self-made       founder non-finance
#
#      gender   age  ...    relationshiptocompany foundingdate gdpcurrentus  \
# 0      male 83.00  ...  former chairman and CEO     1,955.00          NaN
# 1      male   NaN  ...                 relation     1,930.00          NaN
# 2      male   NaN  ...                 relation     1,960.00          NaN
# 3      male   NaN  ...                  founder     1,957.00          NaN
# 4      male 54.00  ...                  founder     1,988.00          NaN
# ...     ...   ...  ...                      ...          ...          ...
# 1648   male 49.00  ...                  founder     1,993.00          NaN
# 1649   male 48.00  ...                  founder     1,992.00          NaN
# 1650   male 45.00  ...                  founder     2,004.00          NaN
# 1651   male 68.00  ...                  founder     1,987.00          NaN
# 1652   male 57.00  ...                  founder     1,992.00          NaN
#
#                  sourceofwealth  \
# 0         television, Univision
# 1     auto dealers, investments
# 2                   diversified
# 3                       banking
# 4          sugar, flour, cement
# ...                         ...
# 1648                diversified
# 1649               construction
# 1650                  port, gas
# 1651                  beverages
# 1652            TV broadcasting
#
#                                                notes  notes2  \
# 0     represented Marlon Brando and Elizabeth Taylor     NaN
# 1       company split between him and cousin in 2000     NaN
# 2                              inherited from father     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
# ...                                              ...     ...
# 1648                                             NaN     NaN
# 1649                         close ties with Gazprom     NaN
# 1650                                             NaN     NaN
# 1651                                             NaN     NaN
# 1652                                             NaN     NaN
#
#                                                     source  \
# 0             http://en.wikipedia.org/wiki/Jerry_Perenchio
# 1            http://en.wikipedia.org/wiki/Al-Futtaim_Group
# 2            http://en.wikipedia.org/wiki/Al-Ghurair_Group
# 3               http://en.wikipedia.org/wiki/Al-Rajhi_Bank
# 4          http://www.forbes.com/profile/abdulsamad-rabiu/
# ...                                                    ...
# 1648              http://www.forbes.com/profile/zhu-yicai/
# 1649          http://www.forbes.com/profile/ziyad-manasir/
# 1650            http://www.summagroup.ru/about/history/en/
# 1651             http://en.wikipedia.org/wiki/Zong_Qinghou
# 1652  http://en.wikipedia.org/wiki/Zygmunt_Solorz-%C5%BBak
#
#                                                                                                                    source_2  \
# 0                                                                        http://www.forbes.com/profile/a-jerrold-perenchio/
# 1                                                                         http://www.al-futtaim.ae/content/groupProfile.asp
# 2                                                                             http://www.alghurair.com/about-us/our-history
# 3                                                    http://www.alrajhibank.com.sa/ar/investor-relations/pages/default.aspx
# 4                          http://www.bloomberg.com/research/stocks/private/person.asp?personId=52999267&privcapId=48855459
# ...                                                                                                                     ...
# 1648                                                                                                                    NaN
# 1649       http://www.themoscowtimes.com/business/article/billionaire-manasir-sells-stake-in-stroigazconsulting/501515.html
# 1650                                                                      http://www.forbes.com/profile/ziyaudin-magomedov/
# 1651  http://mic.com/articles/39659/zong-qinghou-china-s-richest-man-eats-with-his-workers-and-lives-on-20-a-day#.bBPjZBQZw
# 1652                                     No Mob Bosses in This Legal Strategy The New York Times October 25, 2006 Wednesday
#
#                                                                                                                                                                                                                                 source_3  \
# 0     COLUMN ONE; A Hollywood Player Who Owns the Game; A. Jerrold Perenchio has made billions with great instincts, an iron will and a very low profile. Now he's selling Univision -- his way. Los Angeles Times June 20, 2006 Tuesday
# 1                                                                                                                                                                                                                                    NaN
# 2                                                                                                                                                                                                                                    NaN
# 3                                                                                                                                                                http://www.alrajhibank.com.sa/ar/about-us/pages/board-of-directors.aspx
# 4                                                                                                                                                                                                                                    NaN
# ...                                                                                                                                                                                                                                  ...
# 1648                                                                                                                                                                                                                                 NaN
# 1649                                                                                                                                                                                                                                 NaN
# 1650                                                                                                                                                                                                                                 NaN
# 1651                                                                                                                                                                                                                                 NaN
# 1652                                                                                                                                                                                                                                 NaN
#
#      source_4
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 1648      NaN
# 1649      NaN
# 1650      NaN
# 1651      NaN
# 1652      NaN
#
# [1653 rows x 30 columns]

# %% [markdown]
# ## 9) How old is an average billionaire? How old are self-made billionaires  vs. non self-made billionaires?

# %%
df.age.mean().astype(int)
# Out:
# 63

# %%
df.groupby(by= 'selfmade').age.mean().astype(int)
# Out:
# selfmade
# inherited    64
# self-made    62
# Name: age, dtype: int64

# %% [markdown]
# ## 10) Who are the youngest billionaires? Who are the oldest? Make a graph of the distribution of ages.
#
# > **TIP:** You use `.plot()` to graph values in a column independently, but `.hist()` to draw a [histogram](https://www.mathsisfun.com/data/histograms.html) of the distribution of their values

# %%
df.sort_values(by = 'age')
# Out:
#       year                 name  rank    citizenship countrycode  \
# 1172  2014          Perenna Kei  1284      Hong Kong         HKG
# 397   2014     Dustin Moskovitz   202  United States         USA
# 1004  2014      Mark Zuckerberg    21  United States         USA
# 127   2014  Anton Kathrein, Jr.  1270        Germany         DEU
# 394   2014         Drew Houston  1372  United States         USA
# ...    ...                  ...   ...            ...         ...
# 1499  2014        Tsai Cheng-da   988         Taiwan      Taiwan
# 1512  2014     Vanich Chaiyawan   429       Thailand         THA
# 1516  2014   Victor Civita Neto  1540         Brazil         BRA
# 1555  2014             Wang Wei   375          China         CHN
# 1598  2014             Wu Xiong  1565          China         CHN
#
#       networthusbillion   selfmade         typeofwealth  gender   age  ...  \
# 1172               1.30  inherited            inherited  female 24.00  ...
# 397                6.80  self-made  founder non-finance    male 29.00  ...
# 1004              28.50  self-made  founder non-finance    male 29.00  ...
# 127                1.40  inherited            inherited    male 29.00  ...
# 394                1.20  self-made  founder non-finance    male 30.00  ...
# ...                 ...        ...                  ...     ...   ...  ...
# 1499               1.80  inherited            inherited    male   NaN  ...
# 1512               3.70  self-made    self-made finance    male   NaN  ...
# 1516               1.10  inherited            inherited    male   NaN  ...
# 1555               4.00  self-made  founder non-finance    male   NaN  ...
# 1598               1.00  self-made            executive    male   NaN  ...
#
#      relationshiptocompany foundingdate gdpcurrentus        sourceofwealth  \
# 1172              relation     1,996.00          NaN           real estate
# 397                founder     2,004.00          NaN              Facebook
# 1004               founder     2,004.00          NaN              Facebook
# 127               relation     1,919.00          NaN              antennas
# 394                founder     2,007.00          NaN               Dropbox
# ...                    ...          ...          ...                   ...
# 1499              relation     1,962.00          NaN               finance
# 1512              Chairman     1,942.00          NaN  insurance, beverages
# 1516              relation     1,950.00          NaN                 media
# 1555               founder     1,993.00          NaN      delivery service
# 1598                 owner     1,999.00          NaN        infant formula
#
#                                                                 notes  notes2  \
# 1172                                            inherited from father     NaN
# 397                                                               NaN     NaN
# 1004                                                              NaN     NaN
# 127                                                    3rd generation     NaN
# 394                                                               NaN     NaN
# ...                                                               ...     ...
# 1499                                            inherited from father     NaN
# 1512                                                              NaN     NaN
# 1516                                                   3rd generation     NaN
# 1555  2013 Saw investment from outside investors with government ties     NaN
# 1598                                                              NaN     NaN
#
#                                                                       source  \
# 1172                                http://en.wikipedia.org/wiki/Perenna_Kei
# 397                            http://en.wikipedia.org/wiki/Dustin_Moskovitz
# 1004                          http://www.forbes.com/profile/mark-zuckerberg/
# 127                        http://www.forbes.com/profile/anton-kathrein-jr/#
# 394                                http://en.wikipedia.org/wiki/Drew_Houston
# ...                                                                      ...
# 1499                            http://www.forbes.com/profile/tsai-cheng-da/
# 1512  http://www.thailife.com/a-thai-company-for-thai-people/company-history
# 1516                  http://www.forbes.com/profile/roberta-anamaria-civita/
# 1555                                 http://www.forbes.com/profile/wang-wei/
# 1598                                 http://www.forbes.com/profile/wu-xiong/
#
#                                                     source_2  \
# 1172       http://www.loganestate.com/en/about.aspx?ftid=294
# 397          http://www.forbes.com/profile/dustin-moskovitz/
# 1004                                                     NaN
# 127                                                      NaN
# 394           http://en.wikipedia.org/wiki/Dropbox_(service)
# ...                                                      ...
# 1499  https://www.cathayholdings.com/holdings/web/about.aspx
# 1512           Business Times (Singapore) September 16, 1993
# 1516                                                     NaN
# 1555                                                     NaN
# 1598                                                     NaN
#
#                                                   source_3 source_4
# 1172                                                   NaN      NaN
# 397   https://www.facebook.com/facebook/info?tab=page_info      NaN
# 1004                                                   NaN      NaN
# 127                                                    NaN      NaN
# 394            http://www.forbes.com/profile/drew-houston/      NaN
# ...                                                    ...      ...
# 1499                                                   NaN      NaN
# 1512                                                   NaN      NaN
# 1516                                                   NaN      NaN
# 1555                                                   NaN      NaN
# 1598                                                   NaN      NaN
#
# [1653 rows x 30 columns]

# %%
df.age.value_counts().hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 11) Make a scatterplot of net worth compared to age

# %%
df.plot.scatter(x ='age', y = 'networthusbillion')
# Out:
# <AxesSubplot:xlabel='age', ylabel='networthusbillion'>

# %% [markdown]
# ## 13) Make a bar graph of the wealth of the top 10 richest billionaires
#
# > **TIP:** When you make your plot, you'll need to set the `x` and `y` or else your chart will look _crazy_
# >
# > **TIP:** x and y might be the opposite of what you expect them to be

# %%
df.sort_values(by = 'networthusbillion', ascending=False).head(10).plot(kind='barh', x = 'name', y = 'networthusbillion')
# Out:
# <AxesSubplot:ylabel='name'>
